# %% [markdown]
# # Tuple

# %% [markdown]
# ### Q1: Join Tuples if similar initial element
# While working with Python tuples, we can have a problem in which we need to perform concatenation of records from the similarity of initial element. This problem can have applications in data domains such as Data Science.
#
# For eg.
# ```
# Input  : test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
# Output : [(5, 6, 7, 8), (6, 10), (7, 13)]
# ```

# %%
test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
unique = []

for i in test_list:
    unique.append(i[0])
unique = set(unique)

result = []
for i in unique:
    result.append([i])
    for j in test_list:
        if j[0] == i:
            result[-1].append(j[1])
            
print(result)
# Out:
# [[5, 6, 7, 8], [6, 10], [7, 13]]

# %% [markdown]
# ### Q2 Multiply Adjacent elements (both sides) and take the sum of the right and lest side multiplication results.
#
#
# For eg.
# ```
# The original tuple : (1, 5, 7, 8, 10)
# Resultant tuple after multiplication :
#
# (1*5, 1*5+5*7, 7*5 + 7*8, 8*7 + 8*10, 10*8) -> (5, 40, 91, 136, 80)
#
# output-(5, 40, 91, 136, 80)
# ```

# %%
t = (1, 5, 7, 8, 10)

L = []
L.append(t[0] * t[1])


for i in range(1, len(t) -1):
    L.append(t[i] * t[i - 1] + t[i] * t[i + 1])

L.append(t[-1] * t[-2])
print(L)
# Out:
# [5, 40, 91, 136, 80]

# %% [markdown]
# ### Q3: Check if the tuples are the same or not?
# Two tuples would be the same if both tuples have the same element at the same index
# ```
# t1 = (1,2,3,0)
# t2 = (0,1,2,3)
#
# t1 and t2 are not the same
# ```

# %%
t1 = (1, 2, 3, 0)
t2 = (0, 1, 2, 3)

if t1 == t2:
    print("Tuples are same")
else:
    print("Tuples are not same")
# Out:
# Tuples are not same

# %% [markdown]
# ### Q4: Count no of tuples, lists, and sets from a list
# ```
# list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]
#
# ```
# `Output:`
#
# ```
# List-2
# Set-2
# Tuples-1
# ```

# %%
L = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]

output = [0,0,0]
for i in L:
    if type(i) == list:
        output[0] += 1
    elif type(i) == set:
        output[1] += 1
    elif type(i) == tuple:
        output[2] += 1
    else:
        pass

print(f"List-{output[0]}\nSet-{output[1]}\nTuples-{output[2]}")
# Out:
# List-2
# Set-2
# Tuples-1

# %% [markdown]
# ### Q5: Shortlist Students for a Job Role
# Ask the user to input students' records and store them in tuples for each record. Then ask the user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# Show every students record in form of tuples if matches all required criteria.
#
# It is assumed that there will be only one primry skill.
#
# If no such candidate found, print `No such candidate`
#
# `Input:`
# ```
# Enter No of records- 2
# Enter Details of student-1
# Enter Student name- Manohar
# Enter Higher Education- B.Tech
# Enter Primary Skill- Python
# Enter Year of Graduation- 2022
# Enter Details of student-2
# Enter Student name- Ponian
# Enter Higher Education- B.Sc.
# Enter Primary Skill- C++
# Enter Year of Graduation- 2020
#
# Enter Job Role Requirement
# Enter Skill- Python
# Enter Higher Education- B.Tech
# Enter Year of Graduation- 2022
# ```
#
# `Output`
# ```
# ('Manohar', 'B.tech', 'Python', '2022')
# ```

# %%
# Number of student records
n = int(input("Enter No of records- "))

students = []

# Collect each student's details
for i in range(1, n + 1):
    print(f"Enter Details of student-{i}")
    name = input("Enter Student name- ")
    education = input("Enter Higher Education- ")
    skill = input("Enter Primary Skill- ")
    grad_year = input("Enter Year of Graduation- ")
    
    # Store each record as a tuple
    students.append((name, education, skill, grad_year))

# Job role requirement
print("\nEnter Job Role Requirement")
req_skill = input("Enter Skill- ")
req_education = input("Enter Higher Education- ")
req_year = input("Enter Year of Graduation- ")

# Filtering candidates
matched = []

for s in students:
    if s[1] == req_education and s[2] == req_skill and s[3] == req_year:
        matched.append(s)

# Output result
if matched:
    for m in matched:
        print(m)
else:
    print("No such candidate")
# Out:
# Enter No of records-  jfkjs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Number of student records
# ----> 2 n = int(input("Enter No of records- "))
#       4 students = []
#       6 # Collect each student's details
#
# ValueError: invalid literal for int() with base 10: 'jfkjs'

# %% [markdown]
# # Set

# %% [markdown]
# ### Q1: Write a program to find a set of common elements in three lists using sets.
# ```
# Input : ar1 = [1, 5, 10, 20, 40, 80]
#         ar2 = [6, 7, 20, 80, 100]
#         ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
#
# Output : [80, 20]
# ```

# %%
ar1 = set([1, 5, 10, 20, 40, 80])
ar2 = set([6, 7, 20, 80, 100])
ar3 = set([3, 4, 15, 20, 30, 70, 80, 120])

result = (ar1 & ar2) & ar3
print(list(result))
# Out:
# [80, 20]

# %% [markdown]
# ### Q2: Write a program to count the unique number of vowels using sets in a given string. Lowercase and uppercase vowels will be taken as different.
#
# `Input:`
# ```
# Str1 = "hands-on data science mentorship progrAm with live classes at an affordable fee only on Campus.X."
# ```
# `Output:`
# ```
# No of unique vowels-6
# ```

# %%
vowels = set("aeiouAEIOU")
s = set("hands-on data science mentorship progrAm with live classes at an affordable fee only on Campus.X.")

print("No of unique vowels-",len(s & vowels))
# Out:
# No of unique vowels- 6

# %% [markdown]
# ### Q3:  Write a program to Check if a given string is a binary string or not.
#
# A string is said to be binary if it consists of only two unique characters.
#
# Take string input from the user.
#
# ```
# Input: str = "01010101010"
# Output: Yes
#
# Input: str = "1222211"
# Output: Yes
#
# Input: str = "Campusx"
# Output: No
# ```

# %%
s = "010101010"

if len(set(s)) == 2:
    print("Binary.")
else:
    print("Not Binary.")
# Out:
# Binary.

# %% [markdown]
# ### Q4: find union of n arrays.
#
# **Example 1:**
#
# Input:
# ```bash
# [[1, 2, 2, 4, 3, 6],
#  [5, 1, 3, 4],
#  [9, 5, 7, 1],
#  [2, 4, 1, 3]]
# ```
#
# Output:
#
#
# [1, 2, 3, 4, 5, 6, 7, 9]

# %%
L = [[1, 2, 2, 4, 3, 6],
 [5, 1, 3, 4],
 [9, 5, 7, 1],
 [2, 4, 1, 3]]

s = set()

for i in L:
    s.update(i)

print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9}

# %% [markdown]
# ### Q5: Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using **list-comprehension**.
#
# **Example 1:**
#
# Input:
# ```bash
# lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
# ```
#
# Output:
# ```bash
# [9, 10, 4, 5]
# ```
#
# **Example 2:**
#
# Input:
#
# lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
# lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
#
# Output:
#
# [9, 11, 26, 28]

# %%
lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69} 
lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}

[item for item in lst1 if item in lst2]
# Out:
# [9, 11, 26, 28]

# %% [markdown]
# # Dictionary

# %% [markdown]
# ### Q1: Key with maximum unique values
#
# Given a dictionary with values list, extract key whose value has most unique values.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# CampusX
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_dict = {"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# Best
# ```

# %%
test_dict = {"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}

max_value = 0
max_key = ""
for i in test_dict:
    if max_value < len(set(test_dict[i])):
        max_value = len(set(test_dict[i]))
        max_key = i

print(max_key)
# Out:
# Best

# %% [markdown]
# ### Q2: Replace words from the Dictionary. Given a String, replace its words from the lookup dictionary.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}
# ```
#
# Output:
#
# ```bash
# CampusX is the best channel for Data-Science students.
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"good" : "is the best channel", "ds" : "Data-Science"}
# ```
#
# Output:
# ```bash
# CampusX best for DS students.
# ```

# %%
test_str = 'CampusX best for DS students.'
repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}

result = []
for i in test_str.split():
    if i in repl_dict:
        result.append(repl_dict[i])
    else:
        result.append(i)

print(" ".join(result))
# Out:
# CampusX is the best channel for Data-Science students.

# %% [markdown]
# ### Q3: Convert List to List of dictionaries. Given list values and keys list, convert these values to key value pairs in form of list of dictionaries.
#
# **Example 1:**
#
# Input:
# ```bash
# test_list = ["DataScience", 3, "is", 8]
# key_list = ["name", "id"]
#
# Output:
#
# ```bash
# [{'name': 'DataScience', 'id': 3}, {'name': 'is', 'id': 8}]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_list = ["CampusX", 10]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'CampusX', 'id': 10}]
# ```

# %%
test_list = ["DataScience", 3, "is", 8]
key_list = ["name", "id"]

n = len(test_list)
result = []

for i in range(0,n,2):
    result.append({key_list[0]: test_list[i], key_list[1]: test_list[i + 1]})

print(result)
# Out:
# [{'name': 'DataScience', 'id': 3}, {'name': 'is', 'id': 8}]

# %% [markdown]
# ### Q4: Convert a list of Tuples into Dictionary.
#
# **Example 1:**
#
# Input:
# ```bash
# [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
# ```
#
# Output:
# ```bash
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# [('A', 1), ('B', 2), ('C', 3)]
# ```
#
# Output:
# ```bash
# {'A': [1], 'B': [2], 'C': [3]}
# ```

# %%
L = [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
d= {}

for (i,j) in L:
    d[i] = [j]

print(d)
# Out:
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}

# %% [markdown]
# ### Q5: Sort Dictionary key and values List.
#
# **Example 1:**
#
# Input:
#
# ```bash
# {'c': [3], 'b': [12, 10], 'a': [19, 4]}
# ```
#
# Output:
#
# ```bash
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
# ```
#
# **Example 2:**
#
# Input:
#
# ```bash
# {'c': [10, 34, 3]}
# ```
#
# Output:
#
# ```bash
# {'c': [3, 10, 34]}
# ```

# %%
d = {'c': [3], 'b': [12, 10], 'a': [19, 4]}

res = {}
for i in sorted(d):
    res[i] = sorted(d[i])

print(res)
# Out:
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
